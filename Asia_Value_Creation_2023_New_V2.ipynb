# %%
import pandas as pd
from datetime import datetime
import datetime as dt
import numpy as np

# %%
from google.colab import files
files.upload() #Global Opportunities Tracker 20230508 (date)
# Out:
#      <input type="file" id="files-15efe307-ffd1-4f13-b69e-4c381d0eb15f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15efe307-ffd1-4f13-b69e-4c381d0eb15f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('/content/Global Opportunities Tracker 20230614.csv') #pd.read_excel or pd.read_csv

# %%
df.head()
# Out:
#    ID                                        Opportunity Spend Stream Region  \
# 0   5             DCS framework agreement Asia (Emerson)          CAP   Asia
# 1   6                ESD framework agreement Asia (HIMA)          CAP   Asia
# 2   7          Pumps framework agreements Asia (various)          CAP   Asia
# 3   8  Instruments framework agreements Asia (Emerson...          CAP   Asia
# 4   9  Pipes, Valves, Fittings framework agreement As...          CAP   Asia
#
#   Country SBU AS % SBU CC % SBU HPPM % SBU Total % Site  ...      GPLT Lead  \
# 0     MYS      NaN      30%        70%        100%  NaN  ...  Nicholas Heng
# 1     MYS      NaN      30%        70%        100%  NaN  ...  Nicholas Heng
# 2     MYS      NaN      30%        70%        100%  NaN  ...  Nicholas Heng
# 3     MYS      NaN      30%        70%        100%  NaN  ...  Nicholas Heng
# 4     MYS      NaN      30%        70%        100%  NaN  ...  Nicholas Heng
#
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Opportunity', 'Spend Stream', 'Region', 'Country', 'SBU AS %',
#        'SBU CC %', 'SBU HPPM %', 'SBU Total %', 'Site', 'UNSPSC',
#        'ARIBA Event', 'GPLT Lead', 'Procurement Manager', 'Delivery Date',
#        'Duration (months)', 'Value in Current Stage', 'Currency', 'Stage',
#        'Value Creation Type', 'Savings Strategy', 'Benefit Source'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                         int64
# Opportunity               object
# Spend Stream              object
# Region                    object
# Country                   object
# SBU AS %                  object
# SBU CC %                  object
# SBU HPPM %                object
# SBU Total %               object
# Site                      object
# UNSPSC                    object
# ARIBA Event               object
# GPLT Lead                 object
# Procurement Manager       object
# Delivery Date             object
# Duration (months)          int64
# Value in Current Stage    object
# Currency                  object
# Stage                     object
# Value Creation Type       object
# Savings Strategy          object
# Benefit Source            object
# dtype: object

# %%
df['Delivery Date'].head(3)
# Out:
# 0    01/01/2024
# 1    01/01/2024
# 2    01/01/2024
# Name: Delivery Date, dtype: object

# %%
df['Delivery Date'] = pd.to_datetime(df['Delivery Date'],format="%d/%m/%Y") #change object to datetime

# %%
df['Delivery Date'].head(3)
# Out:
# 0   2024-01-01
# 1   2024-01-01
# 2   2024-01-01
# Name: Delivery Date, dtype: datetime64[ns]

# %%
df.dtypes
# Out:
# ID                                 int64
# Opportunity                       object
# Spend Stream                      object
# Region                            object
# Country                           object
# SBU AS %                          object
# SBU CC %                          object
# SBU HPPM %                        object
# SBU Total %                       object
# Site                              object
# UNSPSC                            object
# ARIBA Event                       object
# GPLT Lead                         object
# Procurement Manager               object
# Delivery Date             datetime64[ns]
# Duration (months)                  int64
# Value in Current Stage            object
# Currency                          object
# Stage                             object
# Value Creation Type               object
# Savings Strategy                  object
# Benefit Source                    object
# dtype: object

# %%
df['Stage'].value_counts()
# Out:
# Started     397
# Complete    183
# Scoped      159
# Idea         80
# Stopped      44
# Name: Stage, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# Europe      493
# Asia        174
# Americas    170
# MEA          26
# Name: Region, dtype: int64

# %%
dfa = df.loc[(df['Region']=="Asia") & ~(df['Stage']=="Stopped"),:]

# %%
dfa.head()
# Out:
#    ID                                        Opportunity Spend Stream Region  \
# 0   5             DCS framework agreement Asia (Emerson)          CAP   Asia
# 1   6                ESD framework agreement Asia (HIMA)          CAP   Asia
# 2   7          Pumps framework agreements Asia (various)          CAP   Asia
# 3   8  Instruments framework agreements Asia (Emerson...          CAP   Asia
# 4   9  Pipes, Valves, Fittings framework agreement As...          CAP   Asia
#
#   Country SBU AS % SBU CC % SBU HPPM % SBU Total % Site  ...      GPLT Lead  \
# 0     MYS      NaN      30%        70%        100%  NaN  ...  Nicholas Heng
# 1     MYS      NaN      30%        70%        100%  NaN  ...  Nicholas Heng
# 2     MYS      NaN      30%        70%        100%  NaN  ...  Nicholas Heng
# 3     MYS      NaN      30%        70%        100%  NaN  ...  Nicholas Heng
# 4     MYS      NaN      30%        70%        100%  NaN  ...  Nicholas Heng
#
# ...

# %%
dfa['Stage'].value_counts()
# Out:
# Started     50
# Scoped      45
# Idea        41
# Complete    17
# Name: Stage, dtype: int64

# %%
dfa['Region'].value_counts()
# Out:
# Asia    153
# Name: Region, dtype: int64

# %%
dfa.shape
# Out:
# (153, 22)

# %%
dfa.dtypes
# Out:
# ID                                 int64
# Opportunity                       object
# Spend Stream                      object
# Region                            object
# Country                           object
# SBU AS %                          object
# SBU CC %                          object
# SBU HPPM %                        object
# SBU Total %                       object
# Site                              object
# UNSPSC                            object
# ARIBA Event                       object
# GPLT Lead                         object
# Procurement Manager               object
# Delivery Date             datetime64[ns]
# Duration (months)                  int64
# Value in Current Stage            object
# Currency                          object
# Stage                             object
# Value Creation Type               object
# Savings Strategy                  object
# Benefit Source                    object
# dtype: object

# %%
dfa['Delivery Date'].min()
# Out:
# Timestamp('2022-02-01 00:00:00')

# %%
dfa['Delivery Date'].max()
# Out:
# Timestamp('2027-01-01 00:00:00')

# %%
dfa['Delivery Date'].value_counts().sort_values(ascending=False)
# Out:
# 2023-01-01    46
# 2023-07-01    18
# 2024-01-01    15
# 2023-05-01    13
# 2023-04-01    11
# 2023-03-31     7
# 2025-01-01     7
# 2022-10-01     4
# 2024-06-01     4
# 2022-07-01     3
# 2023-06-01     3
# 2022-02-01     3
# 2022-04-01     2
# 2023-02-01     2
# 2022-03-01     2
# 2023-03-01     2
# 2022-05-01     1
# 2023-10-01     1
# 2027-01-01     1
# 2023-09-01     1
# 2023-12-01     1
# 2026-01-01     1
# 2023-04-16     1
# 2023-01-09     1
# 2023-03-09     1
# 2023-02-21     1
# 2023-04-30     1
# Name: Delivery Date, dtype: int64

# %%
dfa['Delivery Date'].value_counts().sort_index() #value_counts sort by index (date)
# Out:
# 2022-02-01     3
# 2022-03-01     2
# 2022-04-01     2
# 2022-05-01     1
# 2022-07-01     3
# 2022-10-01     4
# 2023-01-01    46
# 2023-01-09     1
# 2023-02-01     2
# 2023-02-21     1
# 2023-03-01     2
# 2023-03-09     1
# 2023-03-31     7
# 2023-04-01    11
# 2023-04-16     1
# 2023-04-30     1
# 2023-05-01    13
# 2023-06-01     3
# 2023-07-01    18
# 2023-09-01     1
# 2023-10-01     1
# 2023-12-01     1
# 2024-01-01    15
# 2024-06-01     4
# 2025-01-01     7
# 2026-01-01     1
# 2027-01-01     1
# Name: Delivery Date, dtype: int64

# %%
#Filter only Delivery Date starting Feb 2022 till Dec 2023

# %%
dfam = dfa.loc[(dfa['Delivery Date']>='2022-02-01') & (dfa['Delivery Date']<='2023-12-31'),:]

# %%
dfam['Delivery Date'].value_counts().sort_index() #value_counts sort by index (date)
# Out:
# 2022-02-01     3
# 2022-03-01     2
# 2022-04-01     2
# 2022-05-01     1
# 2022-07-01     3
# 2022-10-01     4
# 2023-01-01    46
# 2023-01-09     1
# 2023-02-01     2
# 2023-02-21     1
# 2023-03-01     2
# 2023-03-09     1
# 2023-03-31     7
# 2023-04-01    11
# 2023-04-16     1
# 2023-04-30     1
# 2023-05-01    13
# 2023-06-01     3
# 2023-07-01    18
# 2023-09-01     1
# 2023-10-01     1
# 2023-12-01     1
# Name: Delivery Date, dtype: int64

# %%
dfam['Duration (months)'].value_counts()
# Out:
# 12    98
# 1     16
# 3      5
# 6      5
# 2      1
# Name: Duration (months), dtype: int64

# %%
dfam.loc[dfam['Duration (months)']==1,:]
# Out:
#       ID                                        Opportunity Spend Stream  \
# 12    17               Kluang Dispersion Capacity Expansion          CAP
# 30    36                   Kluang RMSB Fire Fighting System          CAP
# 45    51   D&D cost reduction via long term leased isotanks          LOG
# 633  647                  KDE: QP Equipment Storage Shelter          IND
# 663  677                                  Red Panda project          CAP
# 685  706  Ningbo E0100/0120 Condenser maintenance price ...          IND
# 686  707           Ningbo Butterfly valve price negotiation          IND
# 687  708  Caojing Glass Fiber Sample Pads price negotiation          IND
# 689  710  Caojing Security scertification replacement pr...          IND
# 702  723  Red Panda Safety report and Health assessment ...          CAP
# 703  724                 SIL verfication price negotiation           CAP
# 704  725            Red Panda EIA report price negotiation           CAP
# ...

# %%
#dfam.loc[:,'End Date'] = ((dfam['Delivery Date'].dt.to_period('M')) + (dfam['Duration (months)']-1)).dt.to_timestamp()

# %%
dfam.loc[:,'End Date'] = (dfam['Delivery Date'].dt.to_period('M') + dfam['Duration (months)']).dt.to_timestamp()
# Out:
# <ipython-input-29-8b6f6bbdff97>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam.loc[:,'End Date'] = (dfam['Delivery Date'].dt.to_period('M') + dfam['Duration (months)']).dt.to_timestamp()

# %%
dfam.loc[:,'End Date'] = ((dfam['End Date'].dt.to_period('D')) + dfam['Delivery Date'].dt.day-1).dt.to_timestamp()
# Out:
# <ipython-input-30-c43c90125f19>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam.loc[:,'End Date'] = ((dfam['End Date'].dt.to_period('D')) + dfam['Delivery Date'].dt.day-1).dt.to_timestamp()
# <ipython-input-30-c43c90125f19>:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   dfam.loc[:,'End Date'] = ((dfam['End Date'].dt.to_period('D')) + dfam['Delivery Date'].dt.day-1).dt.to_timestamp()

# %%
dfam.loc[:,['Delivery Date', 'Duration (months)', 'End Date']].head()
# Out:
#    Delivery Date  Duration (months)   End Date
# 12    2023-10-01                  1 2023-11-01
# 14    2023-01-01                 12 2024-01-01
# 15    2023-01-01                 12 2024-01-01
# 16    2023-05-01                 12 2024-05-01
# 22    2023-01-01                 12 2024-01-01

# %%
dfam.loc[:,['Delivery Date', 'Duration (months)', 'End Date']].tail()
# Out:
#     Delivery Date  Duration (months)   End Date
# 858    2023-05-01                 12 2024-05-01
# 859    2023-01-01                 12 2024-01-01
# 860    2023-05-01                 12 2024-05-01
# 861    2023-01-01                 12 2024-01-01
# 862    2023-01-01                 12 2024-01-01

# %%
dfam.loc[(dfam['Delivery Date']>='2022-02-01') & (dfam['Delivery Date']<='2022-12-31') & (dfam['End Date']<='2023-12-31'),'Type'] = 'Carry Over'
# Out:
# <ipython-input-33-dec762180fa6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam.loc[(dfam['Delivery Date']>='2022-02-01') & (dfam['Delivery Date']<='2022-12-31') & (dfam['End Date']<='2023-12-31'),'Type'] = 'Carry Over'

# %%
dfam.loc[(dfam['Delivery Date']>='2023-01-01') & (dfam['End Date']<='2023-12-31'),'Type'] = '2023'

# %%
dfam.loc[dfam['Type']=='2023',['Delivery Date', 'Duration (months)', 'End Date', 'Type']].head()
# Out:
#     Delivery Date  Duration (months)   End Date  Type
# 12     2023-10-01                  1 2023-11-01  2023
# 30     2023-01-01                  1 2023-02-01  2023
# 45     2023-01-01                  1 2023-02-01  2023
# 633    2023-03-01                  1 2023-04-01  2023
# 634    2023-04-01                  3 2023-07-01  2023

# %%
dfam.shape
# Out:
# (125, 24)

# %%
#define some important date parameter

# %%
dfam.loc[:,'end_2022'] = datetime.strptime('2022/12/31', '%Y/%m/%d')
dfam.loc[:,'end_2023'] = datetime.strptime('2023/12/31', '%Y/%m/%d')
dfam.loc[:,'start_2023'] = datetime.strptime('2023/01/01', '%Y/%m/%d')
dfam.loc[:,'start_2024'] = datetime.strptime('2024/01/01', '%Y/%m/%d')
# Out:
# <ipython-input-38-a67b7470b3e1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam.loc[:,'end_2022'] = datetime.strptime('2022/12/31', '%Y/%m/%d')
# <ipython-input-38-a67b7470b3e1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam.loc[:,'end_2023'] = datetime.strptime('2023/12/31', '%Y/%m/%d')
# <ipython-input-38-a67b7470b3e1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dfam.loc[:,'start_2023']
# Out:
# 12    2023-01-01
# 14    2023-01-01
# 15    2023-01-01
# 16    2023-01-01
# 22    2023-01-01
#          ...
# 858   2023-01-01
# 859   2023-01-01
# 860   2023-01-01
# 861   2023-01-01
# 862   2023-01-01
# Name: start_2023, Length: 125, dtype: datetime64[ns]

# %%
#dfam.to_csv('clean asia value creation.csv')

# %%
dfam['end_2022']
# Out:
# 12    2022-12-31
# 14    2022-12-31
# 15    2022-12-31
# 16    2022-12-31
# 22    2022-12-31
#          ...
# 858   2022-12-31
# 859   2022-12-31
# 860   2022-12-31
# 861   2022-12-31
# 862   2022-12-31
# Name: end_2022, Length: 125, dtype: datetime64[ns]

# %%
dfam['Type'].value_counts(dropna=False) #dropna=False to see NaN value
# Out:
# NaN           88
# 2023          22
# Carry Over    15
# Name: Type, dtype: int64

# %%
dfam.loc[:,'#month End 2022'] = ((dfam['end_2022'] - dfam['Delivery Date'])/np.timedelta64(1, 'M')).astype('float').round(0)
# Out:
# <ipython-input-43-d487d9c56c78>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam.loc[:,'#month End 2022'] = ((dfam['end_2022'] - dfam['Delivery Date'])/np.timedelta64(1, 'M')).astype('float').round(0)

# %%
dfam.loc[:,'#month End 2024'] = ((dfam['End Date'] - dfam['start_2024'])/np.timedelta64(1, 'M')+1).astype('float').round(0)
# Out:
# <ipython-input-44-9a42c641216c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam.loc[:,'#month End 2024'] = ((dfam['End Date'] - dfam['start_2024'])/np.timedelta64(1, 'M')+1).astype('float').round(0)

# %%
dfam.loc[dfam['#month End 2022']>0,['Delivery Date','End Date','#month End 2022','#month End 2024']].head(5)
# Out:
#    Delivery Date   End Date  #month End 2022  #month End 2024
# 34    2022-02-01 2023-02-01             11.0            -10.0
# 62    2022-04-01 2023-04-01              9.0             -8.0
# 63    2022-05-01 2023-05-01              8.0             -7.0
# 64    2022-10-01 2023-10-01              3.0             -2.0
# 81    2022-04-01 2023-04-01              9.0             -8.0

# %%
dfam.columns
# Out:
# Index(['ID', 'Opportunity', 'Spend Stream', 'Region', 'Country', 'SBU AS %',
#        'SBU CC %', 'SBU HPPM %', 'SBU Total %', 'Site', 'UNSPSC',
#        'ARIBA Event', 'GPLT Lead', 'Procurement Manager', 'Delivery Date',
#        'Duration (months)', 'Value in Current Stage', 'Currency', 'Stage',
#        'Value Creation Type', 'Savings Strategy', 'Benefit Source', 'End Date',
#        'Type', 'end_2022', 'end_2023', 'start_2023', 'start_2024',
#        '#month End 2022', '#month End 2024'],
#       dtype='object')

# %%
dfam.dtypes
# Out:
# ID                                 int64
# Opportunity                       object
# Spend Stream                      object
# Region                            object
# Country                           object
# SBU AS %                          object
# SBU CC %                          object
# SBU HPPM %                        object
# SBU Total %                       object
# Site                              object
# UNSPSC                            object
# ARIBA Event                       object
# GPLT Lead                         object
# Procurement Manager               object
# Delivery Date             datetime64[ns]
# Duration (months)                  int64
# Value in Current Stage            object
# Currency                          object
# Stage                             object
# Value Creation Type               object
# Savings Strategy                  object
# Benefit Source                    object
# End Date                  datetime64[ns]
# ...

# %%
dfam['Value in Current Stage'] = dfam['Value in Current Stage'].str.replace(",","").astype(int)
# Out:
# <ipython-input-48-8ae354981a0b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam['Value in Current Stage'] = dfam['Value in Current Stage'].str.replace(",","").astype(int)

# %%
dfam.loc[dfam['Type']=='Carry Over','2022'] = dfam['Value in Current Stage']/dfam['Duration (months)']*dfam['#month End 2022']
# Out:
# <ipython-input-49-534e09170062>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam.loc[dfam['Type']=='Carry Over','2022'] = dfam['Value in Current Stage']/dfam['Duration (months)']*dfam['#month End 2022']

# %%
dfam['Type'].value_counts(dropna=False)
# Out:
# NaN           88
# 2023          22
# Carry Over    15
# Name: Type, dtype: int64

# %%
dfam.loc[dfam['Type'].isna(),:]
# Out:
#       ID                                        Opportunity Spend Stream  \
# 14    19  Capex synergies for Asia, China sourcing, (ASI...          CAP
# 15    20                             MST Land Lease Renewal          IND
# 16    21                          ACN new tank (NPBT) lease          IND
# 22    27  2023 Malaysia Indirect (OPEX, Packaging, Corpo...          IND
# 23    28   2023 China Indirect (OPEX, Packaging, Corporate)          IND
# ..   ...                                                ...          ...
# 858  881                 Steam flowmeter charge negotiation          IND
# 859  882                         SHE Waste toluene disposal          IND
# 860  883       SHE Liquid nitrogen suplly negotiated saving          IND
# 861  884                Negotiated saving for shipping line          LOG
# 862  885                       MRO supply negotiated saving          IND
#
#     Region Country SBU AS % SBU CC % SBU HPPM % SBU Total % Site  ...  \
# ...

# %%
dfam.loc[dfam['Type'].isna(),'2024'] = dfam['Value in Current Stage']/dfam['Duration (months)']*dfam['#month End 2024']
# Out:
# <ipython-input-52-e2b7f3b6c2bb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam.loc[dfam['Type'].isna(),'2024'] = dfam['Value in Current Stage']/dfam['Duration (months)']*dfam['#month End 2024']

# %%
dfam['Type'].value_counts()
# Out:
# 2023          22
# Carry Over    15
# Name: Type, dtype: int64

# %%
#Create a python list to specify all the conditions
conditions = [(dfam['Type'] == '2023'),
    (dfam['Type'] == 'Carry Over'),
    (dfam['Type'].isna())]

# %%
values = [dfam['Value in Current Stage'], dfam['Value in Current Stage']-dfam['2022'], dfam['Value in Current Stage']-dfam['2024']]

# %%
dfam['2023'] = np.select(conditions, values)
# Out:
# <ipython-input-56-8af01f1e4577>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam['2023'] = np.select(conditions, values)

# %%
dfam.loc[:,'Check'] = dfam['2022'] + dfam['2023'] + dfam['2024'] - dfam['Value in Current Stage']
# Out:
# <ipython-input-57-be74f91f08c5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam.loc[:,'Check'] = dfam['2022'] + dfam['2023'] + dfam['2024'] - dfam['Value in Current Stage']

# %%
dfam[['2022','2023','2024','Value in Current Stage','Check']]
# Out:
#      2022           2023           2024  Value in Current Stage  Check
# 12    NaN  500000.000000            NaN                  500000    NaN
# 14    NaN       0.000000       0.000000                       0    NaN
# 15    NaN  179259.666667   16296.333333                  195556    NaN
# 16    NaN  233333.333333  166666.666667                  400000    NaN
# 22    NaN   45833.333333    4166.666667                   50000    NaN
# ..    ...            ...            ...                     ...    ...
# 858   NaN    8876.583333    6340.416667                   15217    NaN
# 859   NaN   11576.583333    1052.416667                   12629    NaN
# 860   NaN     566.416667     404.583333                     971    NaN
# 861   NaN     398.750000      36.250000                     435    NaN
# 862   NaN    7531.333333     684.666667                    8216    NaN
#
# [125 rows x 5 columns]

# %%
dfam.loc[~dfam['Check'].isna(),:] #check notna means there is decrepency. It should be NO value/data.
# Out:
# Empty DataFrame
# Columns: [ID, Opportunity, Spend Stream, Region, Country, SBU AS %, SBU CC %, SBU HPPM %, SBU Total %, Site, UNSPSC, ARIBA Event, GPLT Lead, Procurement Manager, Delivery Date, Duration (months), Value in Current Stage, Currency, Stage, Value Creation Type, Savings Strategy, Benefit Source, End Date, Type, end_2022, end_2023, start_2023, start_2024, #month End 2022, #month End 2024, 2022, 2024, 2023, Check]
# Index: []
#
# [0 rows x 34 columns]

# %%
dfam.loc[dfam['Check'].isna(),:]
# Out:
#       ID                                        Opportunity Spend Stream  \
# 12    17               Kluang Dispersion Capacity Expansion          CAP
# 14    19  Capex synergies for Asia, China sourcing, (ASI...          CAP
# 15    20                             MST Land Lease Renewal          IND
# 16    21                          ACN new tank (NPBT) lease          IND
# 22    27  2023 Malaysia Indirect (OPEX, Packaging, Corpo...          IND
# ..   ...                                                ...          ...
# 858  881                 Steam flowmeter charge negotiation          IND
# 859  882                         SHE Waste toluene disposal          IND
# 860  883       SHE Liquid nitrogen suplly negotiated saving          IND
# 861  884                Negotiated saving for shipping line          LOG
# 862  885                       MRO supply negotiated saving          IND
#
#     Region Country SBU AS % SBU CC % SBU HPPM % SBU Total % Site  ...  \
# ...

# %%
dfam.columns
# Out:
# Index(['ID', 'Opportunity', 'Spend Stream', 'Region', 'Country', 'SBU AS %',
#        'SBU CC %', 'SBU HPPM %', 'SBU Total %', 'Site', 'UNSPSC',
#        'ARIBA Event', 'GPLT Lead', 'Procurement Manager', 'Delivery Date',
#        'Duration (months)', 'Value in Current Stage', 'Currency', 'Stage',
#        'Value Creation Type', 'Savings Strategy', 'Benefit Source', 'End Date',
#        'Type', 'end_2022', 'end_2023', 'start_2023', 'start_2024',
#        '#month End 2022', '#month End 2024', '2022', '2024', '2023', 'Check'],
#       dtype='object')

# %%
dfam.dtypes
# Out:
# ID                                 int64
# Opportunity                       object
# Spend Stream                      object
# Region                            object
# Country                           object
# SBU AS %                          object
# SBU CC %                          object
# SBU HPPM %                        object
# SBU Total %                       object
# Site                              object
# UNSPSC                            object
# ARIBA Event                       object
# GPLT Lead                         object
# Procurement Manager               object
# Delivery Date             datetime64[ns]
# Duration (months)                  int64
# Value in Current Stage             int64
# Currency                          object
# Stage                             object
# Value Creation Type               object
# Savings Strategy                  object
# Benefit Source                    object
# End Date                  datetime64[ns]
# ...

# %%
#Note: CC=FS, HPPM=PE, AS=IS

# %%
dfam['SBU AS %'].value_counts()
# Out:
# 0%     3
# 25%    2
# 20%    1
# 30%    1
# Name: SBU AS %, dtype: int64

# %%
dfam['SBU HPPM %'].value_counts()
# Out:
# 100%    36
# 50%     29
# 70%      5
# 60%      4
# 25%      2
# 20%      1
# 90%      1
# 40%      1
# 95%      1
# 80%      1
# 75%      1
# 0%       1
# 35%      1
# 30%      1
# Name: SBU HPPM %, dtype: int64

# %%
dfam['SBU AS %'] = dfam['SBU AS %'].str.replace('%','').astype(float)/100
dfam['SBU CC %'] = dfam['SBU CC %'].str.replace('%','').astype(float)/100
dfam['SBU HPPM %'] = dfam['SBU HPPM %'].str.replace('%','').astype(float)/100
# Out:
# <ipython-input-66-7911bbff9743>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam['SBU AS %'] = dfam['SBU AS %'].str.replace('%','').astype(float)/100
# <ipython-input-66-7911bbff9743>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam['SBU CC %'] = dfam['SBU CC %'].str.replace('%','').astype(float)/100
# <ipython-input-66-7911bbff9743>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfam['SBU AS %'].value_counts()
# Out:
# 0.00    3
# 0.25    2
# 0.20    1
# 0.30    1
# Name: SBU AS %, dtype: int64

# %%
dfam['SBU CC %'].value_counts()
# Out:
# 1.00    41
# 0.50    30
# 0.30     6
# 0.40     4
# 0.00     2
# 0.80     1
# 0.10     1
# 0.60     1
# 0.05     1
# 0.20     1
# 0.25     1
# 0.35     1
# 0.70     1
# Name: SBU CC %, dtype: int64

# %%
dfam['SBU HPPM %'].value_counts()
# Out:
# 1.00    36
# 0.50    29
# 0.70     5
# 0.60     4
# 0.25     2
# 0.20     1
# 0.90     1
# 0.40     1
# 0.95     1
# 0.80     1
# 0.75     1
# 0.00     1
# 0.35     1
# 0.30     1
# Name: SBU HPPM %, dtype: int64

# %%
dfam.dtypes
# Out:
# ID                                 int64
# Opportunity                       object
# Spend Stream                      object
# Region                            object
# Country                           object
# SBU AS %                         float64
# SBU CC %                         float64
# SBU HPPM %                       float64
# SBU Total %                       object
# Site                              object
# UNSPSC                            object
# ARIBA Event                       object
# GPLT Lead                         object
# Procurement Manager               object
# Delivery Date             datetime64[ns]
# Duration (months)                  int64
# Value in Current Stage             int64
# Currency                          object
# Stage                             object
# Value Creation Type               object
# Savings Strategy                  object
# Benefit Source                    object
# End Date                  datetime64[ns]
# ...

# %%
#Note: CC=FS, HPPM=PE, AS=IS

# %%
dfam.loc[:,'FS LV'] = dfam['2023']*dfam['SBU CC %']
dfam.loc[:,'PE LV'] = dfam['2023']*dfam['SBU HPPM %']
dfam.loc[:,'IS LV'] = dfam['2023']*dfam['SBU AS %']
# Out:
# <ipython-input-72-e94a81c9c683>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam.loc[:,'FS LV'] = dfam['2023']*dfam['SBU CC %']
# <ipython-input-72-e94a81c9c683>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam.loc[:,'PE LV'] = dfam['2023']*dfam['SBU HPPM %']
# <ipython-input-72-e94a81c9c683>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dfam[['FS LV','PE LV','IS LV']]
# Out:
#              FS LV          PE LV  IS LV
# 12   500000.000000            NaN    NaN
# 14        0.000000       0.000000    NaN
# 15             NaN  179259.666667    NaN
# 16             NaN  233333.333333    NaN
# 22    18333.333333   27500.000000    NaN
# ..             ...            ...    ...
# 858    4438.291667    4438.291667    NaN
# 859            NaN   11576.583333    NaN
# 860            NaN     566.416667    NaN
# 861     199.375000     199.375000    NaN
# 862    3765.666667    3765.666667    NaN
#
# [125 rows x 3 columns]

# %%
date_report = input() #%Y-%m-%d 2023-09-01 (2022 Sep 01 (day always 01))
# Out:
# 2023-05-31

# %%
type(date_report)
# Out:
# str

# %%
date_report = datetime.strptime(date_report, '%Y-%m-%d')

# %%
type(date_report)
# Out:
# datetime.datetime

# %%
date_report
# Out:
# datetime.datetime(2023, 5, 31, 0, 0)

# %%
date_report = date_report.date()

# %%
date_report
# Out:
# datetime.date(2023, 5, 31)

# %%
dfam['date_report_column'] = date_report
# Out:
# <ipython-input-81-432dcb921fb6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam['date_report_column'] = date_report

# %%
dfam['date_report_column']
# Out:
# 12     2023-05-31
# 14     2023-05-31
# 15     2023-05-31
# 16     2023-05-31
# 22     2023-05-31
#           ...
# 858    2023-05-31
# 859    2023-05-31
# 860    2023-05-31
# 861    2023-05-31
# 862    2023-05-31
# Name: date_report_column, Length: 125, dtype: object

# %%
dfam.dtypes
# Out:
# ID                                 int64
# Opportunity                       object
# Spend Stream                      object
# Region                            object
# Country                           object
# SBU AS %                         float64
# SBU CC %                         float64
# SBU HPPM %                       float64
# SBU Total %                       object
# Site                              object
# UNSPSC                            object
# ARIBA Event                       object
# GPLT Lead                         object
# Procurement Manager               object
# Delivery Date             datetime64[ns]
# Duration (months)                  int64
# Value in Current Stage             int64
# Currency                          object
# Stage                             object
# Value Creation Type               object
# Savings Strategy                  object
# Benefit Source                    object
# End Date                  datetime64[ns]
# ...

# %%
#change object to datetime

# %%
dfam['date_report_column'] = pd.to_datetime(dfam['date_report_column'])
# Out:
# <ipython-input-85-17db73091a91>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam['date_report_column'] = pd.to_datetime(dfam['date_report_column'])

# %%
dfam.dtypes
# Out:
# ID                                 int64
# Opportunity                       object
# Spend Stream                      object
# Region                            object
# Country                           object
# SBU AS %                         float64
# SBU CC %                         float64
# SBU HPPM %                       float64
# SBU Total %                       object
# Site                              object
# UNSPSC                            object
# ARIBA Event                       object
# GPLT Lead                         object
# Procurement Manager               object
# Delivery Date             datetime64[ns]
# Duration (months)                  int64
# Value in Current Stage             int64
# Currency                          object
# Stage                             object
# Value Creation Type               object
# Savings Strategy                  object
# Benefit Source                    object
# End Date                  datetime64[ns]
# ...

# %%
dfam['date_report_column']
# Out:
# 12    2023-05-31
# 14    2023-05-31
# 15    2023-05-31
# 16    2023-05-31
# 22    2023-05-31
#          ...
# 858   2023-05-31
# 859   2023-05-31
# 860   2023-05-31
# 861   2023-05-31
# 862   2023-05-31
# Name: date_report_column, Length: 125, dtype: datetime64[ns]

# %%
dfam['medium_1'] = ((dfam['date_report_column'] - dfam['Delivery Date'])/np.timedelta64(1, 'M')).astype('float').round(0)
# Out:
# <ipython-input-88-29b458692d16>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam['medium_1'] = ((dfam['date_report_column'] - dfam['Delivery Date'])/np.timedelta64(1, 'M')).astype('float').round(0)

# %%
dfam['medium_2'] = ((dfam['date_report_column'] - dfam['End Date'])/np.timedelta64(1, 'M')).astype('float').round(0)
# Out:
# <ipython-input-89-56286218fce0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam['medium_2'] = ((dfam['date_report_column'] - dfam['End Date'])/np.timedelta64(1, 'M')).astype('float').round(0)

# %%
dfam['medium_3'] = ((dfam['date_report_column'] - dfam['start_2023'])/np.timedelta64(1, 'M')).astype('float').round(0)
# Out:
# <ipython-input-90-51ec7b366e98>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam['medium_3'] = ((dfam['date_report_column'] - dfam['start_2023'])/np.timedelta64(1, 'M')).astype('float').round(0)

# %%
dfam.loc[:,['Delivery Date','End Date','date_report_column','medium_1','medium_2','medium_3']]
# Out:
#     Delivery Date   End Date date_report_column  medium_1  medium_2  medium_3
# 12     2023-10-01 2023-11-01         2023-05-31      -4.0      -5.0       5.0
# 14     2023-01-01 2024-01-01         2023-05-31       5.0      -7.0       5.0
# 15     2023-01-01 2024-01-01         2023-05-31       5.0      -7.0       5.0
# 16     2023-05-01 2024-05-01         2023-05-31       1.0     -11.0       5.0
# 22     2023-01-01 2024-01-01         2023-05-31       5.0      -7.0       5.0
# ..            ...        ...                ...       ...       ...       ...
# 858    2023-05-01 2024-05-01         2023-05-31       1.0     -11.0       5.0
# 859    2023-01-01 2024-01-01         2023-05-31       5.0      -7.0       5.0
# 860    2023-05-01 2024-05-01         2023-05-31       1.0     -11.0       5.0
# 861    2023-01-01 2024-01-01         2023-05-31       5.0      -7.0       5.0
# 862    2023-01-01 2024-01-01         2023-05-31       5.0      -7.0       5.0
#
# [125 rows x 6 columns]

# %%
dfam.dtypes
# Out:
# ID                                 int64
# Opportunity                       object
# Spend Stream                      object
# Region                            object
# Country                           object
# SBU AS %                         float64
# SBU CC %                         float64
# SBU HPPM %                       float64
# SBU Total %                       object
# Site                              object
# UNSPSC                            object
# ARIBA Event                       object
# GPLT Lead                         object
# Procurement Manager               object
# Delivery Date             datetime64[ns]
# Duration (months)                  int64
# Value in Current Stage             int64
# Currency                          object
# Stage                             object
# Value Creation Type               object
# Savings Strategy                  object
# Benefit Source                    object
# End Date                  datetime64[ns]
# ...

# %%
#Create a python list to specify all the conditions
conditions2 = [(dfam['medium_1'] == 0) & (dfam['medium_2'] == 0),
    (dfam['medium_1'] < 0) & (dfam['medium_2'] < 0),
    (dfam['medium_1'] > 0) & (dfam['medium_2'] > 0) & (dfam['medium_1'] >= dfam['medium_3']),
    (dfam['medium_1'] > 0) & (dfam['medium_2'] > 0) & (dfam['medium_1'] < dfam['medium_3']),
    (dfam['medium_1'] > 0) & (dfam['medium_2'] < 0) & (dfam['medium_1'] >= dfam['medium_3']),
    (dfam['medium_1'] > 0) & (dfam['medium_2'] < 0) & (dfam['medium_1'] < dfam['medium_3'])]

# %%
conditions3 = [(dfam['medium_1'] >= 0) & (dfam['medium_2'] >= 0) & (dfam['Delivery Date'] <= dfam['start_2023']),
    (dfam['medium_1'] >= 0) & (dfam['medium_2'] < 0) & (dfam['Delivery Date'] > dfam['start_2023']),
    (dfam['medium_1'] >= 0) & (dfam['medium_2'] < 0) & (dfam['Delivery Date'] <= dfam['start_2023']),
    (dfam['medium_1'] < 0) & (dfam['medium_2'] < 0),
    (dfam['medium_1'] >= 0) & (dfam['medium_2'] >= 0) & (dfam['Delivery Date'] > dfam['start_2023'])]

# %%
values2 = [round((pd.Timedelta(days=30)/np.timedelta64(1, 'M')),0),
           0,
           ((dfam['End Date']-dfam['start_2023']+pd.Timedelta(days=30))/np.timedelta64(1, 'M')).astype('float').round(0),
           0,
           ((dfam['date_report_column']-dfam['start_2023']+pd.Timedelta(days=30))/np.timedelta64(1, 'M')).astype('float').round(0),
           ((dfam['date_report_column']-dfam['Delivery Date']+pd.Timedelta(days=30))/np.timedelta64(1, 'M')).astype('float').round(0)]

# %%
values3 = [((dfam['End Date']-dfam['start_2023'])/np.timedelta64(1, 'M')).astype('float').round(0),
           ((dfam['date_report_column']-dfam['Delivery Date'])/np.timedelta64(1, 'M')).astype('float').round(0),
           ((dfam['date_report_column']-dfam['start_2023'])/np.timedelta64(1, 'M')).astype('float').round(0),
           0,
           ((dfam['End Date']-dfam['Delivery Date'])/np.timedelta64(1, 'M')).astype('float').round(0)]

# %%
dfam['ACT Effective Month'] = np.select(conditions3, values3)
# Out:
# <ipython-input-97-2890cc811702>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam['ACT Effective Month'] = np.select(conditions3, values3)

# %%
#dfam.to_csv('Clean Asia Creation.csv')

# %%
dfam.columns
# Out:
# Index(['ID', 'Opportunity', 'Spend Stream', 'Region', 'Country', 'SBU AS %',
#        'SBU CC %', 'SBU HPPM %', 'SBU Total %', 'Site', 'UNSPSC',
#        'ARIBA Event', 'GPLT Lead', 'Procurement Manager', 'Delivery Date',
#        'Duration (months)', 'Value in Current Stage', 'Currency', 'Stage',
#        'Value Creation Type', 'Savings Strategy', 'Benefit Source', 'End Date',
#        'Type', 'end_2022', 'end_2023', 'start_2023', 'start_2024',
#        '#month End 2022', '#month End 2024', '2022', '2024', '2023', 'Check',
#        'FS LV', 'PE LV', 'IS LV', 'date_report_column', 'medium_1', 'medium_2',
#        'medium_3', 'ACT Effective Month'],
#       dtype='object')

# %%
dfam.loc[(dfam['Delivery Date']>='2023-03-01') & (dfam['Delivery Date']<='2023-03-31'),['Delivery Date','End Date','date_report_column','Duration (months)','medium_1','medium_2','medium_3','ACT Effective Month']]
# Out:
#     Delivery Date   End Date date_report_column  Duration (months)  medium_1  \
# 633    2023-03-01 2023-04-01         2023-05-31                  1       3.0
# 685    2023-03-31 2023-05-01         2023-05-31                  1       2.0
# 686    2023-03-31 2023-05-01         2023-05-31                  1       2.0
# 687    2023-03-31 2023-05-01         2023-05-31                  1       2.0
# 688    2023-03-31 2024-03-31         2023-05-31                 12       2.0
# 689    2023-03-31 2023-05-01         2023-05-31                  1       2.0
# 704    2023-03-09 2023-04-09         2023-05-31                  1       3.0
# 715    2023-03-31 2024-03-31         2023-05-31                 12       2.0
# 716    2023-03-31 2024-03-31         2023-05-31                 12       2.0
# 854    2023-03-01 2024-03-01         2023-05-31                 12       3.0
#
#      medium_2  medium_3  ACT Effective Month
# 633       2.0       5.0                  1.0
# ...

# %%
dfam.dtypes
# Out:
# ID                                 int64
# Opportunity                       object
# Spend Stream                      object
# Region                            object
# Country                           object
# SBU AS %                         float64
# SBU CC %                         float64
# SBU HPPM %                       float64
# SBU Total %                       object
# Site                              object
# UNSPSC                            object
# ARIBA Event                       object
# GPLT Lead                         object
# Procurement Manager               object
# Delivery Date             datetime64[ns]
# Duration (months)                  int64
# Value in Current Stage             int64
# Currency                          object
# Stage                             object
# Value Creation Type               object
# Savings Strategy                  object
# Benefit Source                    object
# End Date                  datetime64[ns]
# ...

# %%
#ACT

# %%
dfam.loc[:,'FS ACT'] = dfam['Value in Current Stage']*dfam['ACT Effective Month']*dfam['SBU CC %']/dfam['Duration (months)'].round(2)
dfam.loc[:,'PE ACT'] = dfam['Value in Current Stage']*dfam['ACT Effective Month']*dfam['SBU HPPM %']/dfam['Duration (months)'].round(2)
dfam.loc[:,'IS ACT'] = dfam['Value in Current Stage']*dfam['ACT Effective Month']*dfam['SBU AS %']/dfam['Duration (months)'].round(2)
# Out:
# <ipython-input-103-e1219a42942d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam.loc[:,'FS ACT'] = dfam['Value in Current Stage']*dfam['ACT Effective Month']*dfam['SBU CC %']/dfam['Duration (months)'].round(2)
# <ipython-input-103-e1219a42942d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam.loc[:,'PE ACT'] = dfam['Value in Current Stage']*dfam['ACT Effective Month']*dfam['SBU HPPM %']/dfam['Duration (months)'].round(2)
# ...

# %%
dfam['Category'] = ''
dfam['Working Capital'] = ''
dfam['Working Capital Source'] = ''
dfam['Status'] = ''
dfam['Next Steps'] = ''
dfam['Check 2'] = ''
# Out:
# <ipython-input-104-06289ea66ff8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam['Category'] = ''
# <ipython-input-104-06289ea66ff8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfam['Working Capital'] = ''
# <ipython-input-104-06289ea66ff8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dfam.Stage.value_counts()
# Out:
# Started     50
# Scoped      34
# Idea        24
# Complete    17
# Name: Stage, dtype: int64

# %%
dfam.loc[dfam['Stage']=='Complete', ['Delivery Date','End Date','Duration (months)','Stage','Type','Value in Current Stage','2023','FS ACT','PE ACT','IS ACT']]
# Out:
#     Delivery Date   End Date  Duration (months)     Stage        Type  \
# 30     2023-01-01 2023-02-01                  1  Complete        2023
# 34     2022-02-01 2023-02-01                 12  Complete  Carry Over
# 45     2023-01-01 2023-02-01                  1  Complete        2023
# 83     2022-03-01 2023-03-01                 12  Complete  Carry Over
# 149    2022-03-01 2023-03-01                 12  Complete  Carry Over
# 633    2023-03-01 2023-04-01                  1  Complete        2023
# 685    2023-03-31 2023-05-01                  1  Complete        2023
# 686    2023-03-31 2023-05-01                  1  Complete        2023
# 687    2023-03-31 2023-05-01                  1  Complete        2023
# 689    2023-03-31 2023-05-01                  1  Complete        2023
# 702    2023-04-16 2023-05-16                  1  Complete        2023
# 703    2023-01-09 2023-02-09                  1  Complete        2023
# ...

# %%
dfam.dtypes
# Out:
# ID                                 int64
# Opportunity                       object
# Spend Stream                      object
# Region                            object
# Country                           object
# SBU AS %                         float64
# SBU CC %                         float64
# SBU HPPM %                       float64
# SBU Total %                       object
# Site                              object
# UNSPSC                            object
# ARIBA Event                       object
# GPLT Lead                         object
# Procurement Manager               object
# Delivery Date             datetime64[ns]
# Duration (months)                  int64
# Value in Current Stage             int64
# Currency                          object
# Stage                             object
# Value Creation Type               object
# Savings Strategy                  object
# Benefit Source                    object
# End Date                  datetime64[ns]
# ...

# %%
dfinal = dfam.loc[:,['ID','Spend Stream','Region','Country','SBU Total %',
                     'SBU CC %','SBU HPPM %','SBU AS %','Site','UNSPSC','Category',
                     'ARIBA Event','Benefit Source','Opportunity','GPLT Lead','Procurement Manager',
                     'Delivery Date','End Date','Value in Current Stage','Working Capital','Working Capital Source',
                     'Currency','Stage','Value Creation Type','Savings Strategy','Status','Next Steps',
                     '2022','2023','2024','Type','Duration (months)','Check','FS LV','PE LV','IS LV','Check 2',
                     'ACT Effective Month','FS ACT','PE ACT','IS ACT']]

# %%
dfinal.head()
# Out:
#     ID Spend Stream Region Country SBU Total %  SBU CC %  SBU HPPM %  \
# 12  17          CAP   Asia     MYS        100%       1.0         NaN
# 14  19          CAP   Asia     NaN        100%       0.3         0.7
# 15  20          IND   Asia     MYS        100%       NaN         1.0
# 16  21          IND   Asia     MYS        100%       NaN         1.0
# 22  27          IND   Asia     MYS        100%       0.4         0.6
#
#     SBU AS % Site                       UNSPSC  ... Duration (months) Check  \
# 12       NaN  NaN  2315 - Industrial Machinery  ...                 1   NaN
# 14       NaN  NaN                          NaN  ...                12   NaN
# 15       NaN  NaN                          NaN  ...                12   NaN
# 16       NaN  NaN                          NaN  ...                12   NaN
# 22       NaN  NaN                          NaN  ...                12   NaN
#
#             FS LV          PE LV IS LV Check 2 ACT Effective Month  \
# ...

# %%
dfinal.to_csv('Clean Asia Creation.csv')
